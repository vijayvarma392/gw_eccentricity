# %% [markdown]
# Example notebook to demonstrate how to make diagnostic plots using built in methods

# %%
import sys
sys.path.append("../")

import matplotlib.pyplot as plt

from gw_eccentricity import get_available_methods
from gw_eccentricity import measure_eccentricity
from gw_eccentricity.load_data import load_waveform
from gw_eccentricity.compare_methods import compute_errors_between_methods

# %load_ext autoreload
# %autoreload 2
# Out:
# /home1/md.shaikh/miniconda3/envs/eccimrct/lib/python3.8/site-packages/gwtools/rotations.py:63: UserWarning: Could not import GWFrames, needed for rotations module
#   _warnings.warn("Could not import GWFrames, needed for rotations module")
# /home1/md.shaikh/miniconda3/envs/eccimrct/lib/python3.8/site-packages/gwtools/__init__.py:11: UserWarning: Could not import rotations, decompositions, or fitfuncs. These are not needed by GWSurrogate.
#   _warnings.warn("Could not import rotations, decompositions, or fitfuncs. These are not needed by GWSurrogate.")

# %%
import glob
import matplotlib.pyplot as plt
from gw_eccentricity.plot_settings import use_fancy_plotsettings, figWidthsOneColDict, colorsDict
import matplotlib as mpl
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
available_param_sets = {
    "1": [1, 0, 0],
    "2": [2, 0.5, 0.5],
    "3": [4, -0.6, -0.6],
    "4": [6, 0.4, -0.4]}

# %%
param_set = "3"
num_orbits_to_exclude_before_merger = 5

# %%
q, chi1, chi2 = available_param_sets[param_set]
eob_waveforms = sorted(glob.glob(f"../data/ecc_waveforms/Non-Precessing/EOB/EccTest_q{q:.2f}_chi1z{chi1:.2f}_chi2z{chi2:.2f}_*_Momega00.010_meanAno1.571.h5"))

# %%
def compute_errors(method1, method2, waveform_path, zeroecc_waveform_path):
    extra_kwargs = {"debug": False,
                    "num_orbits_to_exclude_before_merger": num_orbits_to_exclude_before_merger}
    waveform_keywords = {
        "filepath": waveform_path,
        "filepath_zero_ecc": zeroecc_waveform_path,
        "include_zero_ecc": True}
    dataDict = load_waveform(catalog="EOB", **waveform_keywords)
    tref_vec = dataDict["t"]
    tref_out1, ecc_vec1, mean_ano_vec1, gwecc_obj1 = measure_eccentricity(
        tref_in=tref_vec,
        dataDict=dataDict,
        method=method1, 
        return_gwecc_object=True,
        extra_kwargs=extra_kwargs)
    tref_out2, ecc_vec2, mean_ano_vec2, gwecc_obj2 = measure_eccentricity(
        tref_in=tref_vec,
        dataDict=dataDict,
        method=method2, 
        return_gwecc_object=True,
        extra_kwargs=extra_kwargs)
    t, ecc_errors, mean_ano_errors = compute_errors_between_methods(gwecc_obj1, gwecc_obj2)[:3]
    
    return t, ecc_errors, mean_ano_errors, gwecc_obj1, gwecc_obj2

# %%
zeroecc_path = f"../data/ecc_waveforms/Non-Precessing/EOB/EccTest_q{q:.2f}_chi1z{chi1:.2f}_chi2z{chi2:.2f}_EOBecc0.0000000000_Momega00.002_meanAno1.571.h5"
t, ecc_errs, mean_ano_errs, gwecc_obj1, gwecc_obj2 = compute_errors("ResidualAmplitude", "FrequencyFits", eob_waveforms[140], zeroecc_path)

# %%
style = "Notebook"
use_fancy_plotsettings(style=style)
fig, ax = plt.subplots(figsize=(figWidthsOneColDict[journal], 4))
ax.plot(t, ecc_errs, label="ecc errors")
ax.set_xlabel(r"$t$ [$M$]")
ax.set_ylabel(r"Difference in $e$")
ax.legend()

# %%
style = "Notebook"
use_fancy_plotsettings(style=style)
fig, ax = plt.subplots(figsize=(figWidthsOneColDict[journal], 4))
ax.plot(t, mean_ano_errs, label="mean ano errors")
ax.set_xlabel(r"$t$ [$M$]")
ax.set_ylabel(r"Difference in mean anomaly")
ax.legend()

# %%
style = "Notebook"
use_fancy_plotsettings(style=style)
fig, ax = plt.subplots(figsize=(figWidthsOneColDict[journal], 4))
ax.plot(gwecc_obj1.tref_out, gwecc_obj1.ecc_ref, label=gwecc_obj1.method)
ax.plot(gwecc_obj2.tref_out, gwecc_obj2.ecc_ref, label=gwecc_obj2.method, ls="--")
ax.set_xlabel(r"$t$ [$M$]")
ax.set_ylabel(r"$e$")
ax.legend()

# %% [markdown]
# ### Loop over all eob waveforms in set 1 and compute the max error in eccentricity

# %%
import re
from tqdm import tqdm
import numpy as np

# %%
ecc_max_errs = []
t_max_errs = []
eccs = []
failed_cases = []
failed_eccs = []
tmaxes = []
tmins = []
zeroecc_path_set1 = "../data/ecc_waveforms/Non-Precessing/EOB/EccTest_q1.00_chi1z0.00_chi2z0.00_EOBecc0.0000000000_Momega00.002_meanAno1.571.h5"
for waveform in tqdm(eob_waveforms):
    # get the ecc from waveform path string
    ecc = re.search("\d.\d{10}", waveform)[0]
    try:
        t, ecc_errs, mean_ano_errs, gwecc_obj1, gwecc_obj2 = compute_errors("ResidualAmplitude", "FrequencyFits", waveform, zeroecc_path)
        eccs.append(float(ecc))
        ecc_max_errs.append(max(np.abs(ecc_errs)))
        t_max_errs.append(t[np.abs(ecc_errs).argmax()])
        tmins.append([gwecc_obj1.t_min, gwecc_obj2.t_min])
        tmaxes.append([gwecc_obj1.t_max, gwecc_obj2.t_max])
    except Exception:
        failed_eccs.append(ecc)
        failed_cases.append(waveform)
ecc_max_errs = np.array(ecc_max_errs)
t_max_errs = np.array(t_max_errs)
eccs = np.array(eccs)
failed_cases = np.array(failed_cases)
failed_eccs = np.array(failed_eccs)
tmaxes = np.array(tmaxes)
tmins = np.array(tmins)
# Out:
#   0%|                                                                                                                                                                                      | 0/150 [00:00<?, ?it/s]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:465: UserWarning: Encountered negative eccentricity.
#   warnings.warn("Encountered negative eccentricity.")
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:662: UserWarning: Number of pericenters and number of apocenters differ by 2. This implies that pericenters and apocenters are not appearing alternately.
#   warnings.warn(
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:614: UserWarning: Phase shift closer to pi than 2 pi detected.
#   warnings.warn("Phase shift closer to pi than 2 pi detected.")
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.874916485162856. Times of occurrences are [-20900.92695723]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   1%|█▏                                                                                                                                                                            | 1/150 [00:02<07:14,  2.92s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881754774738511. Times of occurrences are [-20902.92676511]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   1%|██▎                                                                                                                                                                           | 2/150 [00:05<06:48,  2.76s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.882825676763815. Times of occurrences are [-20897.92574548]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   2%|███▍                                                                                                                                                                          | 3/150 [00:08<06:53,  2.82s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881969009485147. Times of occurrences are [-20902.9263383]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   3%|████▋                                                                                                                                                                         | 4/150 [00:11<06:43,  2.77s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.882825463816786. Times of occurrences are [-20897.92623297]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   3%|█████▊                                                                                                                                                                        | 5/150 [00:13<06:45,  2.80s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.880898892228558. Times of occurrences are [-20907.92659256]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   4%|██████▉                                                                                                                                                                       | 6/150 [00:16<06:45,  2.82s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881754880960017. Times of occurrences are [-20903.92652513]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   5%|████████                                                                                                                                                                      | 7/150 [00:19<06:38,  2.79s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.875141786710529. Times of occurrences are [-20899.92654945]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   5%|█████████▎                                                                                                                                                                    | 8/150 [00:22<06:47,  2.87s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.892778191753351. Times of occurrences are [-20909.92662419]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   6%|██████████▍                                                                                                                                                                   | 9/150 [00:25<06:35,  2.80s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.883468017394804. Times of occurrences are [-20908.9262041]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   7%|███████████▌                                                                                                                                                                 | 10/150 [00:27<06:19,  2.71s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881112831237758. Times of occurrences are [-20906.92663159]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   7%|████████████▋                                                                                                                                                                | 11/150 [00:30<06:07,  2.65s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.880899001306588. Times of occurrences are [-20907.9263458]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   8%|█████████████▊                                                                                                                                                               | 12/150 [00:32<06:01,  2.62s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881540839295184. Times of occurrences are [-20904.9265557]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   9%|██████████████▉                                                                                                                                                              | 13/150 [00:35<05:55,  2.59s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.8940642161797285. Times of occurrences are [-20902.92625786]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#   9%|████████████████▏                                                                                                                                                            | 14/150 [00:37<05:50,  2.58s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881754853186436. Times of occurrences are [-20902.92658767]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  10%|█████████████████▎                                                                                                                                                           | 15/150 [00:40<05:44,  2.55s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.893421026132714. Times of occurrences are [-20906.92662745]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  11%|██████████████████▍                                                                                                                                                          | 16/150 [00:42<05:41,  2.55s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.881326588023285. Times of occurrences are [-20905.92712024]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  11%|███████████████████▌                                                                                                                                                         | 17/150 [00:45<05:36,  2.53s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.879829419571664. Times of occurrences are [-20913.92663967]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  12%|████████████████████▊                                                                                                                                                        | 18/150 [00:47<05:34,  2.53s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.891064914187012. Times of occurrences are [-20918.92674653]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  13%|█████████████████████▉                                                                                                                                                       | 19/150 [00:50<05:32,  2.54s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.892563927794242. Times of occurrences are [-20910.92669707]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  13%|███████████████████████                                                                                                                                                      | 20/150 [00:53<05:29,  2.53s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.880043166167852. Times of occurrences are [-20912.92686054]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  14%|████████████████████████▏                                                                                                                                                    | 21/150 [00:55<05:27,  2.54s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.871767675661445. Times of occurrences are [-20916.92671692]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  15%|█████████████████████████▎                                                                                                                                                   | 22/150 [00:58<05:26,  2.55s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.8717676230298395. Times of occurrences are [-20916.92683032]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  15%|██████████████████████████▌                                                                                                                                                  | 23/150 [01:00<05:23,  2.55s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.889994824521338. Times of occurrences are [-20924.92687801]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  16%|███████████████████████████▋                                                                                                                                                 | 24/150 [01:03<05:16,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.878760488996363. Times of occurrences are [-20919.92674685]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  17%|████████████████████████████▊                                                                                                                                                | 25/150 [01:05<05:14,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.869970362876742. Times of occurrences are [-20926.92698492]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  17%|█████████████████████████████▉                                                                                                                                               | 26/150 [01:08<05:12,  2.52s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.888070093548194. Times of occurrences are [-20935.9270809]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  18%|███████████████████████████████▏                                                                                                                                             | 27/150 [01:10<05:07,  2.50s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.887215271457336. Times of occurrences are [-20938.92709044]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  19%|████████████████████████████████▎                                                                                                                                            | 28/150 [01:13<05:07,  2.52s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.8874288869271965. Times of occurrences are [-20938.92721599]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  19%|█████████████████████████████████▍                                                                                                                                           | 29/150 [01:15<05:04,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.9116863076885835. Times of occurrences are [-20945.92705978]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  20%|██████████████████████████████████▌                                                                                                                                          | 30/150 [01:18<05:00,  2.50s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.911508520938. Times of occurrences are [-20946.92708162]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  21%|███████████████████████████████████▊                                                                                                                                         | 31/150 [01:20<04:57,  2.50s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 3.067514254757403. Times of occurrences are [-21711.92730692]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.932204772279491. Times of occurrences are [-20959.92730692]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  21%|████████████████████████████████████▉                                                                                                                                        | 32/150 [01:23<04:56,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 3.087611748400275. Times of occurrences are [-21709.92733301]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.943886354207507. Times of occurrences are [-20957.92733301]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  22%|██████████████████████████████████████                                                                                                                                       | 33/150 [01:25<04:53,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 3.0474173012477386. Times of occurrences are [-21713.92741978]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.931848617174808. Times of occurrences are [-20961.92741978]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  23%|███████████████████████████████████████▏                                                                                                                                     | 34/150 [01:28<04:50,  2.50s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.9469418766683053. Times of occurrences are [-21723.92813563]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.910833945426603. Times of occurrences are [-20971.92813563]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  23%|████████████████████████████████████████▎                                                                                                                                    | 35/150 [01:30<04:47,  2.50s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.8464821837009886. Times of occurrences are [-21733.92829964]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 8.052177583954432. Times of occurrences are [-20981.92829964]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  24%|█████████████████████████████████████████▌                                                                                                                                   | 36/150 [01:33<04:46,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.8766184828902692. Times of occurrences are [-21730.92750062]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 8.017546324294955. Times of occurrences are [-20979.92750062]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  25%|██████████████████████████████████████████▋                                                                                                                                  | 37/150 [01:35<04:44,  2.51s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.776169832937664. Times of occurrences are [-21740.92751568]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.890073525150271. Times of occurrences are [-20987.92751568]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  25%|███████████████████████████████████████████▊                                                                                                                                 | 38/150 [01:38<04:42,  2.52s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.705864694340103. Times of occurrences are [-21747.92775097]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.894057531576436. Times of occurrences are [-20995.92775097]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  26%|████████████████████████████████████████████▉                                                                                                                                | 39/150 [01:40<04:40,  2.52s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.635567427703676. Times of occurrences are [-21754.92824767]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.9843041677980295. Times of occurrences are [-21001.92824767]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  27%|██████████████████████████████████████████████▏                                                                                                                              | 40/150 [01:43<04:38,  2.53s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.555236848537195. Times of occurrences are [-21762.92705769]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.989578158293185. Times of occurrences are [-21008.92705769]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  27%|███████████████████████████████████████████████▎                                                                                                                             | 41/150 [01:45<04:34,  2.52s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.51507481958841. Times of occurrences are [-21766.92865352]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.951848654170533. Times of occurrences are [-21012.92865352]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  28%|████████████████████████████████████████████████▍                                                                                                                            | 42/150 [01:48<04:34,  2.54s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:662: UserWarning: Number of pericenters and number of apocenters differ by 3. This implies that pericenters and apocenters are not appearing alternately.
#   warnings.warn(
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.464875751220871. Times of occurrences are [-21771.92837009]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.985101025607307. Times of occurrences are [-21018.92837009]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  29%|█████████████████████████████████████████████████▌                                                                                                                           | 43/150 [01:50<04:31,  2.53s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.404641890366869. Times of occurrences are [-21777.93787233]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 8.721849179033839. Times of occurrences are [-21024.93787233]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  29%|██████████████████████████████████████████████████▋                                                                                                                          | 44/150 [01:53<04:28,  2.54s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.3444137487353967. Times of occurrences are [-21783.93793418]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 7.999621810322935. Times of occurrences are [-21029.93793418]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  30%|███████████████████████████████████████████████████▉                                                                                                                         | 45/150 [01:56<04:26,  2.54s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:608: UserWarning: At least a pair of apocenters are too close. Minimum orbital phase diff is 2.304264028777959. Times of occurrences are [-21787.93836941]
#   warnings.warn(f"At least a pair of {extrema_type} are too close."
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:626: UserWarning: At least a pair of apocenters are too far. Maximum orbital phase diff is 8.102381773668526. Times of occurrences are [-21034.93836941]
#   warnings.warn(f"At least a pair of {extrema_type} are too far."
#  31%|██████████████████████████████████████████████████████▏                                                                                                                      | 47/150 [02:01<04:24,  2.56s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinition.py:662: UserWarning: Number of pericenters and number of apocenters differ by 4. This implies that pericenters and apocenters are not appearing alternately.
#   warnings.warn(
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 149/150 [06:56<00:03,  3.39s/it]/home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinitionUsingFrequencyFits.py:34: RuntimeWarning: overflow encountered in double_scalars
#   A = f0*(T-self.t0)**(-n)
# /home1/md.shaikh/Eccentricity/notebook/../gw_eccentricity/eccDefinitionUsingFrequencyFits.py:43: RuntimeWarning: invalid value encountered in multiply
#   return A*(T-t)**n
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150/150 [07:10<00:00,  2.87s/it]

# %%
failed_eccs
# Out:
# array([], dtype=float64)

# %% [markdown]
# ### Make scatter plot of absolute errors

# %%
cmap = cm.get_cmap("plasma")
style = "APS"
use_fancy_plotsettings(style=style)
fig, ax = plt.subplots(figsize=(figWidthsOneColDict[style], 3))
scatter = ax.scatter(eccs, ecc_max_errs, c=-np.array(t_max_errs),
                     cmap=cmap,
                     # s=15,
                     marker=".")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel(r"$e_\mathrm{EOB}$ at $\omega_0$")
ax.set_ylabel("maximum difference in $e$")
ax.set_title(fr"$q={q:.1f}$, $\chi_{{1z}}={chi1:.1f}$, $\chi_{{2z}}={chi2:.1f}$", ha="center")

# set major ticks
locmaj = mpl.ticker.LogLocator(base=10, numticks=20)
ax.xaxis.set_major_locator(locmaj)
# set minor ticks
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(0.1, 1.0, 0.1),
                               numticks=20)
ax.xaxis.set_minor_locator(locmin)
ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())

ax.set_xlim(1e-7, 1.0)

# add colorbar
norm = mpl.colors.LogNorm(-np.array(t_max_errs).max(), -np.array(t_max_errs).min())
# levels = np.append(np.array([-t_max_errs.max()]), np.arange(2e3, 15e3, 2e3))
# levels = np.append(levels, np.array([-t_max_errs.min()]))
# levels = np.linspace(1e3, 6.5e4, 5)
# norm = mpl.colors.BoundaryNorm(levels, ncolors=cmap.N, clip=True)
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='3%', pad=0.1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
cbar = fig.colorbar(sm, cax=cax, orientation='vertical')
cbar.set_label(r"time to merger at maximum difference")

# indicate methods
ax.text(0.05, 0.99, f"{gwecc_obj1.method} vs {gwecc_obj2.method}", ha="left", va="top",
       transform=ax.transAxes)
ax.text(0.05, 0.9, fr"\noindent number of orbits to \\exclude before merger = {num_orbits_to_exclude_before_merger}", ha="left", va="top",
       transform=ax.transAxes)
fig.tight_layout()
fig.savefig(f"max_ecc_erros_{gwecc_obj1.method}_{gwecc_obj2.method}_paramset_{param_set}_num_orbits_{num_orbits_to_exclude_before_merger}.pdf")

# %% [markdown]
# ### plot the tmin and tmax

# %%
use_fancy_plotsettings(journal=journal)
fig, ax = plt.subplots(figsize=(figWidthsOneColDict[journal], 3))
# ax.plot(eccs, -tmins[:, 0], c=colorsDict[gwecc_obj1.method], marker=".", markersize=3, ls="", label=rf"$t_\mathrm{{min}}$ {gwecc_obj1.method}")
# ax.plot(eccs, -tmins[:, 1], c=colorsDict[gwecc_obj2.method], marker=".", markersize=3, ls="", label=rf"$t_\mathrm{{min}}$ {gwecc_obj2.method}")

ax.plot(eccs, -tmaxes[:, 0], c=colorsDict[gwecc_obj1.method], marker=".", markersize=3, ls="", label=rf"{gwecc_obj1.method}")
ax.plot(eccs, -tmaxes[:, 1], c=colorsDict[gwecc_obj2.method], marker=".", markersize=3, ls="", label=rf"{gwecc_obj2.method}")

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel(r"$e_\mathrm{EOB}$ at $\omega_0$")
ax.set_ylabel("Time to merger at maximum $t$ [$M$]")
ax.set_title(fr"$q={q:.1f}$, $\chi_{{1z}}={chi1:.1f}$, $\chi_{{2z}}={chi2:.1f}$", ha="center")

# set major ticks
locmaj = mpl.ticker.LogLocator(base=10, numticks=20)
ax.xaxis.set_major_locator(locmaj)
# set minor ticks
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(0.1, 1.0, 0.1),
                               numticks=20)
ax.xaxis.set_minor_locator(locmin)
ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())

ax.set_xlim(1e-7, 1.0)

ax.legend()
fig.tight_layout()
fig.savefig(f"tmax_{gwecc_obj1.method}_{gwecc_obj2.method}_paramset_{param_set}_num_orbits_{num_orbits_to_exclude_before_merger}.png")
